# %% [markdown]
# <a href="https://colab.research.google.com/github/doosanman/-PRJ_Movie_for_you/blob/main/special10_matplotlib_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

plt.rcParams['figure.dpi'] = 50

# %%
fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('figure')
plt.show()

# %%
X = [0, 1]
Y = [0, 1]
fig = plt.figure(figsize=(8, 5))
ax = [None, None, None]
ax[0] = fig.add_axes([0.1, 0.1, 0.4, 0.8])
ax[1] = fig.add_axes([0.55, 0.15, 0.35, 0.4])
ax[2] = fig.add_axes([0.65, 0.6, 0.2, 0.3])

plt.show()

# %%
fig, ax = plt.subplots(2, 3 , figsize=(8, 5))
ax[1, 1].plot(X, Y)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac45a6f8ba7f> in <module>()
# ----> 1 fig, ax = plt.subplots(2, 3 , figsize=(8, 5))
#       2 ax[1, 1].plot(X, Y)
#       3 plt.tight_layout()
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots()
axin1 = ax.inset_axes([0.8, 0.1, 0.15, 0.15])
plt.show()

# %%
fig = plt.figure(figsize=(16, 10))
ax = []
ax.append(plt.subplot2grid((3, 4), (0, 0), colspan=4))
ax.append(plt.subplot2grid((3, 4), (1, 0), colspan=1))
ax.append(plt.subplot2grid((3, 4), (1, 1), colspan=1))
ax.append(plt.subplot2grid((3, 4), (1, 2), colspan=1))
ax.append(plt.subplot2grid((3, 4), (1, 3), colspan=1, rowspan=2))
ax.append(plt.subplot2grid((3, 4), (2, 0), colspan=3))
plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
gs = fig.add_gridspec(3, 3)
ax = [None for _ in range(5)]

ax[0] = fig.add_subplot(gs[0, :])

ax[1] = fig.add_subplot(gs[1, :-1])

ax[2] = fig.add_subplot(gs[1:, -1])

ax[3] = fig.add_subplot(gs[2, 0])

ax[4] = fig.add_subplot(gs[2, 1])

for i in range(5):
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

fig, ax = plt.subplots(1, 1)
ax_divider = make_axes_locatable(ax)

ax = ax_divider.append_axes('right', size='7%', pad='2%')
plt.show()

# %%
import numpy as np
import math

def sigmoid(X):
    sig = 1 / (1 + math.exp(-X))
    return sig
def c_to_f(X):
    return X * 1.8 + 32
point = 100
X = np.linspace(-10, 10, point)
Y = X**2
fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0, 0, 1, 1])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 110)
ax.plot(X, Y, color='black', linewidth=2)

plt.axhline()
plt.axvline()
plt.show()

# %%
point = 50
X = np.linspace(-10, 10, point)

fig = plt.figure(figsize=(8, 5))
ax = fig.add_axes([0, 0, 1, 1])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 110)
ax.plot(X, X**2, 'r-D', X, np.sin(X)*10, 'b-^', X, 2*X+3, 'g-s')

n = 50
x = np.random.rand(n) * 20 - 10
y = np.random.rand(n) * 120 - 10
custom_colors = np.random.rand(n)
area = (30 * np.random.rand(n))**2
ax.scatter(x, y, s=area, c=custom_colors, alpha=0.5)

plt.axhline()
plt.axvline()
plt.show()

# %%
sizes = [20, 30, 45, 10]
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
explode = [0, 0.1, 0, 0]
fig, axes = plt.subplots(figsize=(9, 4))
wedges, _, _ = axes.pie(sizes, startangle=-90, autopct='%.2f%%', 
         labels=labels, explode=explode, 
         shadow=True)
wedges[0].set_radius(1.1)
wedges[2].set(hatch='///', alpha=0.7)
axes.axis('equal')
plt.show()

# %%
size = 0.3
vals1 = [40, 35, 25]
vals2 = [11, 29, 12, 23, 12, 13]
outer_explode = [0, 0.2, 0]
inner_explode = [0, 0, 0.1, 0.1, 0, 0]
cmap = plt.get_cmap('tab20c')
outer_colors = cmap([0, 4, 12])
inner_colors = cmap([1, 2, 5, 6, 13, 14])

fig = plt.figure(figsize=(8, 5))
axes = fig.add_axes([0, 0, 1, 1])
axes.pie(vals1, radius=1, colors=outer_colors,
         labels=['male', 'female', 'pet'],
         autopct='%.1f%%', pctdistance=0.83,
         wedgeprops={'width':size, 'edgecolor':'w',
                     'linewidth':2})
axes.pie(vals2, radius=1 - size, colors=inner_colors,
         autopct='%.1f%%', pctdistance=0.8,
         textprops={'color':'w', 'size':10},
         wedgeprops={'width':size, 'edgecolor':'w',
                     'linewidth':2})
plt.show()

# %%
cmap = 'tab20c'

fig = plt.figure(figsize=(8, 5))
axes = fig.add_axes([0, 0, 1, 1], frameon=False, xticks=[], yticks=[])
Z = np.linspace(0, 1, 512).reshape(1, 512)

plt.imshow(Z, extent=[0, 30, 0, 5], cmap=plt.get_cmap(cmap))
plt.show()

# %%
print(len(plt.colormaps()))
plt.colormaps()
# Out:
# 164
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  'afmhot',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


cmaps_list = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Cyclic', ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral',
            'gist_ncar'])]


gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axs = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)

    axs[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, cmap_name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap_name)
        ax.text(-.01, .5, cmap_name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps_list:
    plot_color_gradients(cmap_category, cmap_list)

plt.show()

# %%
# !pip install colorspacious

# %%
cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list

# %%
# %matplotlib inline

# %%
from matplotlib import cm
from colorspacious import cspace_converter
import matplotlib as mpl
mpl.rcParams.update({'font.size': 12})

# Number of colormap per subplot for particular cmap categories
_DSUBS = {'Perceptually Uniform Sequential': 5, 'Sequential': 6,
          'Sequential (2)': 6, 'Diverging': 6, 'Cyclic': 3,
          'Qualitative': 4, 'Miscellaneous': 6}

# Spacing between the colormaps of a subplot
_DC = {'Perceptually Uniform Sequential': 1.4, 'Sequential': 0.7,
       'Sequential (2)': 1.4, 'Diverging': 1.4, 'Cyclic': 1.4,
       'Qualitative': 1.4, 'Miscellaneous': 1.4}

# Indices to step through colormap
x = np.linspace(0.0, 1.0, 100)

# Do plot
for cmap_category, cmap_list in cmaps.items():

    # Do subplots so that colormaps have enough space.
    # Default is 6 colormaps per subplot.
    dsub = _DSUBS.get(cmap_category, 6)
    nsubplots = int(np.ceil(len(cmap_list) / dsub))

    # squeeze=False to handle similarly the case of a single subplot
    fig, axs = plt.subplots(nrows=nsubplots, squeeze=False,
                            figsize=(8, 5))

    for i, ax in enumerate(axs.flat):

        locs = []  # locations for text labels

        for j, cmap in enumerate(cmap_list[i*dsub:(i+1)*dsub]):

            # Get RGB values for colormap and convert the colormap in
            # CAM02-UCS colorspace.  lab[0, :, 0] is the lightness.
            rgb = cm.get_cmap(cmap)(x)[np.newaxis, :, :3]
            lab = cspace_converter("sRGB1", "CAM02-UCS")(rgb)

            # Plot colormap L values.  Do separately for each category
            # so each plot can be pretty.  To make scatter markers change
            # color along plot:
            # https://stackoverflow.com/q/8202605/

            if cmap_category == 'Sequential':
                # These colormaps all start at high lightness but we want them
                # reversed to look nice in the plot, so reverse the order.
                y_ = lab[0, ::-1, 0]
                c_ = x[::-1]
            else:
                y_ = lab[0, :, 0]
                c_ = x

            dc = _DC.get(cmap_category, 1.4)  # cmaps horizontal spacing
            ax.scatter(x + j*dc, y_, c=c_, cmap=cmap, s=300, linewidths=0.0)

            # Store locations for colormap labels
            if cmap_category in ('Perceptually Uniform Sequential',
                                 'Sequential'):
                locs.append(x[-1] + j*dc)
            elif cmap_category in ('Diverging', 'Qualitative', 'Cyclic',
                                   'Miscellaneous', 'Sequential (2)'):
                locs.append(x[int(x.size/2.)] + j*dc)

        # Set up the axis limits:
        #   * the 1st subplot is used as a reference for the x-axis limits
        #   * lightness values goes from 0 to 100 (y-axis limits)
        ax.set_xlim(axs[0, 0].get_xlim())
        ax.set_ylim(0.0, 100.0)

        # Set up labels for colormaps
        ax.xaxis.set_ticks_position('top')
        ticker = mpl.ticker.FixedLocator(locs)
        ax.xaxis.set_major_locator(ticker)
        formatter = mpl.ticker.FixedFormatter(cmap_list[i*dsub:(i+1)*dsub])
        ax.xaxis.set_major_formatter(formatter)
        ax.xaxis.set_tick_params(rotation=50)
        ax.set_ylabel('Lightness $L^*$', fontsize=12)

    ax.set_xlabel(cmap_category + ' colormaps', fontsize=14)

    fig.tight_layout(h_pad=0.0, pad=1.5)
    plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, -27)
womenMeans = (25, 32, 34, 20, -25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)
width = 0.35

# %%
fig = plt.figure(figsize=(8,5))
axes = fig.add_axes([0, 0, 1, 1])
axes.bar(ind, menMeans, 0.35, label='Men', 
         alpha=0.9, yerr=menStd)
axes.bar(ind, womenMeans, 0.35, label='Women', 
         alpha=0.9, bottom=menMeans,
         yerr=womenStd)
axes.axhline(color='k')
axes.set_ylabel('Scores')
axes.set_title('Scores by group and gender')
plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)
width = 0.35

# %%
fig, axes = plt.subplots()
axes.bar(ind - width/2, menMeans, width, label='Men')
axes.bar(ind + width/2, womenMeans, width, label='Women')
axes.set_ylabel('Scores')
axes.set_title('Scores by group and gender')
axes.legend()
plt.show()

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic_age = titanic[['age', 'survived']].dropna()
print(titanic_age.head())
titanic_age.info()
print(titanic.age.max())
# Out:
#     age  survived
# 0  22.0         0
# 1  38.0         1
# 2  26.0         1
# 3  35.0         1
# 4  35.0         0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       714 non-null    float64
#  1   survived  714 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 16.7 KB
# 80.0

# %%
def age_band(num):
    for i in range(1, 10):
        if num < 10 * i:
            return 'under {}'.format(10 *i)
titanic_age['age_band'] = titanic_age['age'].apply(age_band)
titanic_age.info()
print(titanic_age.head())
print(titanic_age.age_band.max())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       714 non-null    float64
#  1   survived  714 non-null    int64
#  2   age_band  714 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 22.3+ KB
#     age  survived  age_band
# 0  22.0         0  under 30
# 1  38.0         1  under 40
# 2  26.0         1  under 30
# 3  35.0         1  under 40
# 4  35.0         0  under 40
# under 90

# %%
titanic_age = titanic_age[['age_band', 'survived']].groupby('age_band')['survived'].value_counts().sort_index().unstack().fillna(0)
titanic_age
# Out:
# survived      0     1
# age_band
# under 10   24.0  38.0
# under 20   61.0  41.0
# under 30  143.0  77.0
# under 40   94.0  73.0
# under 50   55.0  34.0
# under 60   28.0  20.0
# under 70   13.0   6.0
# under 80    6.0   0.0
# under 90    0.0   1.0

# %%
titanic_age['Survival rate'] = titanic_age[1] / (titanic_age[0] + titanic_age[1]) * 100
titanic_age
# Out:
# survived      0     1  Survival rate
# age_band
# under 10   24.0  38.0      61.290323
# under 20   61.0  41.0      40.196078
# under 30  143.0  77.0      35.000000
# under 40   94.0  73.0      43.712575
# under 50   55.0  34.0      38.202247
# under 60   28.0  20.0      41.666667
# under 70   13.0   6.0      31.578947
# under 80    6.0   0.0       0.000000
# under 90    0.0   1.0     100.000000

# %%
from matplotlib.ticker import FuncFormatter
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

axes[0].bar(titanic_age['Survival rate'].index, titanic_age['Survival rate'], color='gray')
axes[0].set_title('Age band & Survival rate(Before)')

color_map = ['gray'] * 9
color_map[0] = color_map[8] = '#3caea3'


with plt.xkcd():
    axes[1].bar(titanic_age['Survival rate'].index,
                titanic_age['Survival rate'], alpha=0.7,
                color=color_map, edgecolor='k')
    axes[1].set_title('Age band & Survival rate(After)', 
                    fontsize=15, fontweight='bold',
                    position=(0.45, 1.0 + 0.1))
    for i, rate in enumerate(titanic_age['Survival rate']):
        axes[1].annotate(f'{rate:.02f}%',
                        xy=(i, rate + 2),
                        va='center', ha='center', fontweight='bold',
                        color='#383838')
    axes[1].yaxis.set_major_formatter(FuncFormatter(lambda y, _ : f'{y:}%'))
    axes[1].set_xticklabels(titanic_age.index, rotation=45, size=10)
    plt.suptitle('* Focus on survival rates for young and old', color='gray',
                x=0.72, y=0.9)

plt.tight_layout()
plt.show()

# %%
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
titanic_embarked = titanic[['embarked', 'survived']].dropna()
titanic_embarked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   embarked  889 non-null    object
#  1   survived  889 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 20.8+ KB

# %%
titanic_embarked = titanic_embarked.groupby('embarked')['survived'].value_counts().sort_index()

# %%
print(titanic_embarked)
print(type(titanic_embarked))
print(list(titanic_embarked))
# Out:
# embarked  survived
# C         0            75
#           1            93
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: survived, dtype: int64
# <class 'pandas.core.series.Series'>
# [75, 93, 47, 30, 427, 217]

# %%
x_value = ['-'.join(map(str, i)) for i in titanic_embarked.index]
x_value
# Out:
# ['C-0', 'C-1', 'Q-0', 'Q-1', 'S-0', 'S-1']

# %%
with plt.xkcd(1):
    fig, axes = plt.subplots(1, 1, figsize=(8, 5))
    axes.bar(x_value, list(titanic_embarked), color='#e0e0e0', width=0.52, edgecolor='k')
    axes.set_xticklabels(['survived', 'die'] * 3)
    custom_color = ['green', 'blue', 'orange']
    span_range = [[0, 1], [2, 3], [4, 5]]
    for idx, sub_title in enumerate(['Cherbourg', 'Queenstown', 'Southampton']):
        axes.annotate(sub_title,
                    xy=(sum(span_range[idx])/2, 350),
                    xytext=(0,0), textcoords='offset points',
                    fontsize=18, ha='center', va='center',
                    color='r',
                    bbox=dict(boxstyle='round4', pad=0.4,
                            color=custom_color[idx], alpha=0.6))
        axes.axvspan(span_range[idx][0]-0.4, span_range[idx][1]+0.4,
                    color=custom_color[idx], alpha=0.3,
                    hatch='///')
    # plt.axhline(150, linewidth=8, color='seagreen')
    # plt.axvline(1, linewidth=8, color='papayawhip')
    # plt.axhspan(200, 300, facecolor='0.5', alpha=0.5)
plt.show()

# %%
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
iris_df = pd.DataFrame(iris.data, 
                       columns=iris.feature_names)
iris_df['species'] = [iris.target_names[i] for i in iris.target]
iris_df.info()
iris_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2   setosa
# 1                4.9               3.0  ...               0.2   setosa
# 2                4.7               3.2  ...               0.2   setosa
# 3                4.6               3.1  ...               0.2   setosa
# 4                5.0               3.6  ...               0.2   setosa
#
# [5 rows x 5 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

axes[0].scatter(x='petal length (cm)', y='petal width (cm)', 
                data=iris_df, color='gray')
axes[0].set_title('Before')

axes[1].scatter(x='petal length (cm)', y='petal width (cm)',
                data=iris_df[iris_df['species']=='setosa'], 
                color='olive', alpha=0.5, label='setosa')
axes[1].scatter(x='petal length (cm)', y='petal width (cm)',
                data=iris_df[iris_df['species']=='versicolor'], 
                color='palevioletred', alpha=0.5, label='versicolor')
axes[1].scatter(x='petal length (cm)', y='petal width (cm)',
                data=iris_df[iris_df['species']=='virginica'], 
                color='plum', alpha=0.5, label='virginica')
axes[1].set_title('After', fontsize=15, fontweight='bold')
axes[1].legend()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
color_map = ['gray'] * 20
color_map[9] = color_map[10] = '#3caea3'

N = 100000

dist1 = np.random.normal(0, 2, N)
dist2 = np.random.normal(0, 10, N)

fig, axes = plt.subplots(1, 2, sharey=True, tight_layout=True, figsize=(15, 5))
N, bins, patches = axes[0].hist(dist1, bins=20)
axes[0].set_xlim(-31,30)
for i, patch in enumerate(patches):
    patch.set_facecolor(color_map[i])
axes[1].hist(dist2, bins=20)

plt.show()

# %%
fig, axes = plt.subplots(figsize=(5, 8))

axes.hist2d(dist1, dist2, bins=40)
axes.axis('equal')
plt.show()

# %%
fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(projection='3d')
hist, xedges, yedges = np.histogram2d(dist1, dist2, bins=40, range=[[-7, 7], [-30, 30]])

xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing='ij')
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

dx = dy = 0.3 * np.ones_like(zpos)
dz = hist.ravel()


ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')
ax.view_init(elev=40.0, azim=65)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(200, 25, 1000)
w = np.random.normal(200, 10, 1000)

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes[0, 0].hist(x, 20, density=True, histtype='stepfilled', facecolor='g', alpha=0.7)
axes[0, 0].set_title('stepfilled')
axes[0, 1].hist(x, 20, density=True, histtype='step', facecolor='g', alpha=0.7)
axes[0, 1].set_title('step')
axes[1, 0].hist(x, density=True, histtype='barstacked', rwidth=0.7)
axes[1, 0].hist(w, density=True, histtype='barstacked', rwidth=0.7)
axes[1, 0].set_title('barstacked')

bins = [100, 150, 180, 195, 205, 220, 250, 300]
axes[1, 1].hist(x, bins, density=True, histtype='bar', rwidth=0.8)
axes[1, 1].set_title('bar, unequal bins')

plt.show()

# %%
mu = 100
sigma = 15
x = np.random.normal(mu, sigma, 1000000)
num_bins = 50
fig, axes = plt.subplots()
n, bins, patches = axes.hist(x, num_bins, density=True)

y = ((1 / (np.sqrt(2 * np.pi) * sigma))) * np.exp(-0.5 * (1 / sigma * (bins - mu)) ** 2)
axes.plot(bins, y, '--')
plt.show()

# %%
x = np.random.uniform(1, 7, 60000000)

fig, axes = plt.subplots()
n, bins, patches = axes.hist(x, 50, density=True)

plt.show()
